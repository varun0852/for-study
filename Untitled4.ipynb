# %% [markdown]
# <a href="https://colab.research.google.com/github/varun0852/for-study/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# !pip install langchain-aws
# !pip install langchain-classic
from langchain_aws import ChatBedrock
# from langchain.memory import ConversationBufferMemory
from langchain_classic.memory import ConversationBufferMemory
from langchain_classic.chains import ConversationChain
# from langchain_classic.chains import ...



def demo_chatbot():
    demo_llm = ChatBedrock(
        credentials_profile_name = "default",
        model_id = "ai21.jamba-1-5-mini-v1:0",
        model_kwargs = {
            "temperature" : 0.4,
            "max_gen_len": 300
        }
    )
    return demo_llm

def demo_memory():
    llm = demo_chatbot()
    memory = ConversationBufferMemory(llm = llm, max_token_limit = 300)
    return memory

def demo_conversation(input_text , memory):
    llm_chain_data = demo_chatbot()
    llm_conversation = ConversationChain(llm = llm_chain_data , memory = memory , verbose = True)
    chat_reply = llm_conversation.predict(input = input_text)
    return chat_reply , memory
# Out:
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-740148795.py in <cell line: 0>()
#       2 get_ipython().system('pip install langchain-aws')
#       3 get_ipython().system('pip install langchain-classic')
# ----> 4 from langchain_aws import ChatBedrock
#       5 # from langchain.memory import ConversationBufferMemory
#       6 from langchain_classic.memory import ConversationBufferMemory
#
# /usr/local/lib/python3.12/dist-packages/langchain_aws/__init__.py in <module>
#       1 from typing import Any
#       2
# ----> 3 from langchain_aws.chains import (
#       4     create_neptune_opencypher_qa_chain,
#       5     create_neptune_sparql_qa_chain,
#
# /usr/local/lib/python3.12/dist-packages/langchain_aws/chains/__init__.py in <module>
# ----> 1 from langchain_aws.chains.graph_qa import (
#       2     create_neptune_opencypher_qa_chain,
# ...

# %%
import os
os.environ['AWS_ACCESS_KEY_ID'] = ''
os.environ['AWS_SECRET_ACCESS_KEY'] = 'J7t8Ei/Dh/t/T5iT6+uCKgYKvKe+e3PQGjBPuZag'
os.environ['AWS_REGION'] = 'us-east-1'

# %%
# !pip install streamlit
import streamlit as st
import backend as demo

st.title("Varun AI Chatbot using Bedrock (Jamba 1.5 mini)")

# Initializing Memory And Chat History only once
if 'memory' not in st.session_state:
    st.session_state.memory = demo.demo_memory()

if 'chat_history' not in st.session_state:
    st.session_state.chat_history = []

# Display Messages
for message in st.session_state.chat_history:
    with st.chat_message(message["role"]):
        st.markdown(message["text"])

# Handle user Input
input_text = st.chat_input("Use this Chatbot Powered by Jamba 1.5 mini")
if input_text:

    #show user input
    with st.chat_message("user"):
        st.markdown(input_text)
    st.session_state.chat_history.append({"role": "user", "text": input_text})

    # Get Response + updated memory
    response, updated_memory = demo.demo_conversation(
        input_text = input_text,
        memory=st.session_state.memory

    )
    st.session_state.memory = updated_memory # save Memory Updates

    # Show
    with st.chat_message("assistant"):
        st.markdown(response)
    st.session_state.chat_history.append({"role": "assistant" , "text": response
    })
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2323256373.py in <cell line: 0>()
#       1 # !pip install streamlit
#       2 import streamlit as st
# ----> 3 import backend as demo
#       4
#       5 st.title("Varun AI Chatbot using Bedrock (Jamba 1.5 mini)")
#
# /content/backend.py in <module>
#       1 import os
# ----> 2 from langchain_aws import ChatBedrock
#       3 from langchain_classic.memory import ConversationBufferMemory
#       4 from langchain_classic.chains import ConversationChain
#       5
#
# /usr/local/lib/python3.12/dist-packages/langchain_aws/__init__.py in <module>
#       1 from typing import Any
#       2
# ----> 3 from langchain_aws.chains import (
#       4     create_neptune_opencypher_qa_chain,
#       5     create_neptune_sparql_qa_chain,
#
# /usr/local/lib/python3.12/dist-packages/langchain_aws/chains/__init__.py in <module>
# ...

# %%
# %%writefile backend.py
import os
from langchain_aws import ChatBedrock
from langchain_classic.memory import ConversationBufferMemory
from langchain_classic.chains import ConversationChain

def demo_chatbot():
    demo_llm = ChatBedrock(
        # Removed credentials_profile_name to allow automatic detection of environment variables
        model_id = "ai21.jamba-1-5-mini-v1:0",
        model_kwargs = {
            "temperature" : 0.4,
            "max_gen_len": 300
        }
    )
    return demo_llm

def demo_memory():
    llm = demo_chatbot()
    memory = ConversationBufferMemory(llm = llm, max_token_limit = 300)
    return memory

def demo_conversation(input_text , memory):
    llm_chain_data = demo_chatbot()
    llm_conversation = ConversationChain(llm = llm_chain_data , memory = memory , verbose = True)
    chat_reply = llm_conversation.predict(input = input_text)
    return chat_reply , memory
# Out:
# Overwriting backend.py
