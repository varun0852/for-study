# %% [markdown]
# <a href="https://colab.research.google.com/github/varun0852/for-study/blob/master/Accuracy_Improving_on_Boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import linear_model # PARAMETRIC MODEL
from sklearn.tree import DecisionTreeRegressor # NON PARAMETRIC MODEL
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import Normalizer , StandardScaler , MinMaxScaler

# %% [markdown]
# Do EDA and Identify and Treat Outlier and check the model accuracy
#
# Extend this with Forward Addition and Backward Elimination and check the Accuracy
#
# **Perform** Normalization and Standardization and check the accuracy (check customer churn dataset for ideas)

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
df = pd.read_csv("Boston.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
del df["Unnamed: 0"] # DELETING UNNECESSARY COLUMN

# %%
df1 = df.drop("medv" , axis = 1)

# %%
sns.boxplot(df1)
# Out:
# <Axes: >

# %%
Q1 = df1["crim"].quantile(0.25)
Q3 = df1["crim"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.15*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df1[(df1["crim"] >= lower_fence) & (df1["crim"]<= upper_fence)]

# %%
Q1 = df["zn"].quantile(0.25)
Q3 = df["zn"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df1["zn"] >= lower_fence) & (df["zn"]<= upper_fence)]

# %%
Q1 = df["indus"].quantile(0.25)
Q3 = df["indus"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["indus"] >= lower_fence) & (df["indus"]<= upper_fence)]

# %%
Q1 = df["chas"].quantile(0.25)
Q3 = df["chas"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["chas"] >= lower_fence) & (df["chas"]<= upper_fence)]

# %%
Q1 = df["nox"].quantile(0.25)
Q3 = df["nox"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["nox"] >= lower_fence) & (df["nox"]<= upper_fence)]

# %%
Q1 = df["rm"].quantile(0.25)
Q3 = df["rm"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["rm"] >= lower_fence) & (df["rm"]<= upper_fence)]

# %%
Q1 = df["age"].quantile(0.25)
Q3 = df["age"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["age"] >= lower_fence) & (df["age"]<= upper_fence)]

# %%
Q1 = df["dis"].quantile(0.25)
Q3 = df["dis"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["dis"] >= lower_fence) & (df["dis"]<= upper_fence)]

# %%
Q1 = df["rad"].quantile(0.25)
Q3 = df["rad"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["rad"] >= lower_fence) & (df["rad"]<= upper_fence)]

# %%
Q1 = df["tax"].quantile(0.25)
Q3 = df["tax"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["tax"] >= lower_fence) & (df["tax"]<= upper_fence)]

# %%
Q1 = df["ptratio"].quantile(0.25)
Q3 = df["ptratio"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["ptratio"] >= lower_fence) & (df["ptratio"]<= upper_fence)]

# %%
Q1 = df["black"].quantile(0.25)
Q3 = df["black"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["black"] >= lower_fence) & (df["black"]<= upper_fence)]

# %%
Q1 = df["lstat"].quantile(0.25)
Q3 = df["lstat"].quantile(0.75)
iqr = Q3-Q1
lower_fence = Q1-1.5*iqr
upper_fence = Q3+1.5*iqr
trimmed_features = df[(df["lstat"] >= lower_fence) & (df["lstat"]<= upper_fence)]

# %%
sns.boxplot(trimmed_features)
# Out:
# <Axes: >

# %%
x = trimmed_features.drop("medv" , axis = 1) # INPUT
y = trimmed_features["medv"] # OUTPUT

# %%
# negative_counts = 0 # use to check corrupted value
# for i in ["crim"]:
#   if i < 0:
#     negative_counts += 1
# print(negative_counts)

# %%
duplicates = df[df.duplicated()]# use to check duplicates
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, black, lstat, medv]
# Index: []

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 1142)

# %%
print(x_train.head())
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 298   0.06466  70.0   2.24     0  0.400  6.345  20.1  7.8278    5  358
# 426  12.24720   0.0  18.10     0  0.584  5.837  59.7  1.9976   24  666
# 161   1.46336   0.0  19.58     0  0.605  7.489  90.8  1.9709    5  403
# 504   0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 444  12.80230   0.0  18.10     0  0.740  5.854  96.6  1.8956   24  666
#
#      ptratio   black  lstat
# 298     14.8  368.24   4.97
# 426     20.2   24.65  15.69
# 161     14.7  374.43   1.73
# 504     21.0  393.45   6.48
# 444     20.2  240.52  23.79
# (399,)
# (100, 13)
# (100,)

# %%
regr = linear_model.LinearRegression()
# regr = DecisionTreeRegressor()

# %%
regr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
# PRINTING COEFFICIENT
print("Coefficient:" , regr.coef_)
print("Intercept:" , regr.intercept_)
# Out:
# Coefficient: [-1.20090628e-01  3.74242315e-02  7.16165081e-02  3.32809950e+00
#  -1.56205117e+01  4.14492410e+00  1.98771058e-03 -1.33229045e+00
#   3.05555994e-01 -1.38412219e-02 -8.99468556e-01  1.11199351e-02
#  -5.83401815e-01]
# Intercept: 31.59505479716416

# %%
# TESTING
y_pred = regr.predict(x_test)

# %%
y_pred
# Out:
# array([17.80040994, 21.06345415, 33.96174165,  4.04172986, 23.04003444,
#        30.33548093, 23.85971405, 12.2580767 , 17.23523964, 16.02796998,
#        37.21769678, 13.66070535, 24.47861576, 24.2325735 , 22.9386537 ,
#        19.331582  , 10.69784664, 23.69000063, 22.44152342, 20.94426404,
#        10.14997701, 19.83087754, 25.32622116,  8.26632715, 33.70355006,
#         4.79013558, 29.5162112 , 28.49498117, 29.29782058, 27.95229709,
#        23.22345475, 22.63433065, 19.36718748, 40.99010339, 30.48105962,
#         7.83509376, 20.07236549, 16.77682446, 17.2345152 , 11.57433305,
#        17.25886346, 31.32532598, 19.51266132, 12.94236868, 22.76466353,
#        23.14676149, 33.91715632, 21.03328414, 30.64897318, 16.13637704,
#        27.05606561, 20.10562096, 21.53298304, 24.00945614, 22.50652878,
#        26.09572535, 14.94261264, 22.99977984, 23.63508208, 20.66358291,
#        39.49911934, 33.81452515, 28.559449  , 27.23946136,  7.6215069 ,
# ...

# %%
# EVALUATION FOR TEST DATA
y_pred = regr.predict(x_test)
print(f"R2Score: {r2_score(y_test , y_pred):.3f}") # Coefficient of Determination
print(f"MSE: {mean_squared_error(y_test , y_pred):.3f}")
# Out:
# R2Score: 0.725
# MSE: 23.500

# %%
# TESTING ACCURACY
y_pred_tr = regr.predict(x_train)

# %%
# EVALUATION FOR TRAIN DATA
y_pred_tr =  regr.predict(x_train)
print(f"R2Score: {r2_score(y_train , y_pred_tr):.3f}") # Coefficient of Determination
print(f"MSE: {mean_squared_error(y_train , y_pred_tr):.3f}")
# Out:
# R2Score: 0.763
# MSE: 19.763

# %% [markdown]
# # **Perform** Normalization and Standardization and check the accuracy

# %% [markdown]
# ## NORMALIZATION

# %%
# NORMALIZATION BOTH INPUT AND OUTPUT DATA
normalizer = MinMaxScaler()
df_n = normalizer.fit_transform(trimmed_features)
df_n = pd.DataFrame(trimmed_features)
df_n
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df_n.drop("medv" , axis = 1)

# %%
x1 = df_n.drop("medv" , axis = 1) # INPUT
y1 = df_n["medv"] # OUTPUT

# %%
x_train_n , x_test_n , y_train_n , y_test_n = train_test_split(x1 , y1 , test_size = 0.2 , random_state = 1142)

# %%
print(x_train_n.head())
print(y_train_n.shape)
print(x_test_n.shape)
print(y_test_n.shape)

# %%
regr.fit(x_train_n , y_train_n)

# %%
# PRINTING COEFFICIENT
print("Coefficient:" , regr.coef_)
print("Intercept:" , regr.intercept_)

# %%
# TESTING
y_pred_n = regr.predict(x_test_n)
y_pred_n

# %%
# EVALUATION FOR TEST DATA
y_pred_n = regr.predict(x_test_n)
print(f"R2Score: {r2_score(y_test_n , y_pred_n):.3f}") # Coefficient of Determination
print(f"MSE: {mean_squared_error(y_test_n , y_pred_n):.3f}")

# %%
# TESTING ACCURACY
y_pred_tr_n = regr.predict(x_train_n)

# %%
# EVALUATION FOR TRAIN DATA
y_pred_tr_n =  regr.predict(x_train_n)
print(f"R2Score: {r2_score(y_train_n , y_pred_tr_n):.3f}") # Coefficient of Determination
print(f"MSE: {mean_squared_error(y_train_n , y_pred_tr_n):.3f}")

# %% [markdown]
# Extend this with Forward Addition and Backward Elimination and check the Accuracy
